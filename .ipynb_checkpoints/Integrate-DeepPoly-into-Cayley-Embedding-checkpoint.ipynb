# %%
include("CayleyVerify.jl")
include("DeepPoly.jl")

# utility functions
function dorefa_to_staircase(k::Int)
    n = 2^k - 1
    slopes = zeros(n+1)
    breakpoints = [-Inf]
    for i in 1:n
        push!(breakpoints, (2*i-1)/n - 1)
    end
    push!(breakpoints, Inf)
    
    constant_terms = [-1.0]
    for i in 1:n
        push!(constant_terms, -1.0 + 2*i/n)
    end
    return StaircaseFunction(breakpoints, slopes, constant_terms)
end

function predict(neural_net, img)
    num_layers = length(neural_net.weights)
    a = img'
    for i in 1:num_layers
        a = a * neural_net.weights[i] + neural_net.biases[i]'
        if i <= num_layers -1
            a = [eval(neural_net.activation[i], a[j]) for j in 1:length(a)]'
            print(a)
            print("\n----\n")
        end
    end
    output = a'
    print(output)
    return findmax(output)[2]
end
# Out:
# predict (generic function with 1 method)

# %%
import Pickle
using Suppressor
net_from_pickle = Pickle.load(open("models/MNIST-DoReFa2_Dense256-Dense256.pkl"))
f = dorefa_to_staircase(2)
activation = [f, f]
neural_net = NeuralNetwork(net_from_pickle, activation)
print("net loaded")
# Out:
# SystemError: opening file "models/MNIST-DoReFa2_Dense256-Dense256.pkl": No such file or directory
#
# Stacktrace:
#  [1] systemerror(p::String, errno::Int32; extrainfo::Nothing)
#    @ Base ./error.jl:168
#  [2] #systemerror#62
#    @ ./error.jl:167 [inlined]
#  [3] systemerror
#    @ ./error.jl:167 [inlined]
#  [4] open(fname::String; lock::Bool, read::Nothing, write::Nothing, create::Nothing, truncate::Nothing, append::Nothing)
#    @ Base ./iostream.jl:293
#  [5] open(fname::String)
#    @ Base ./iostream.jl:282
#  [6] top-level scope
#    @ In[5]:3
#  [7] eval
#    @ ./boot.jl:360 [inlined]
#  [8] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %%
raw_imgs = Pickle.load(open("/Users/tuna/Documents/Projects/LinSepVerify/imgs/MNIST_images-for-verification"))
imgs = []
for img in raw_imgs
    img = vcat([w' for w in img] ...)
    img = vcat(img'...)
    push!(imgs, img)
end
labels = Pickle.load(open("/Users/tuna/Documents/Projects/LinSepVerify/imgs/MNIST_labels-for-verification"))
labels = Array{Int64}(labels.args[2][5])
labels = [l+1 for l in labels]
print("images loaded")
# Out:
# SystemError: opening file "/Users/tuna/Documents/Projects/LinSepVerify/imgs/MNIST_images-for-verification": No such file or directory
#
# Stacktrace:
#  [1] systemerror(p::String, errno::Int32; extrainfo::Nothing)
#    @ Base ./error.jl:168
#  [2] #systemerror#62
#    @ ./error.jl:167 [inlined]
#  [3] systemerror
#    @ ./error.jl:167 [inlined]
#  [4] open(fname::String; lock::Bool, read::Nothing, write::Nothing, create::Nothing, truncate::Nothing, append::Nothing)
#    @ Base ./iostream.jl:293
#  [5] open(fname::String)
#    @ Base ./iostream.jl:282
#  [6] top-level scope
#    @ In[3]:1
#  [7] eval
#    @ ./boot.jl:360 [inlined]
#  [8] include_string(mapexpr::typeof(REPL.softscope), mod::Module, code::String, filename::String)
#    @ Base ./loading.jl:1116

# %% [markdown]
# # Big-M Formulation

# %%
eps = 0.008
robust = 150
for (i,img) in enumerate(imgs)
    print("verified image number %i", i)
    mip, variable_neuron_dict, neuron_integervar_dict = init_mip_deeppoly(neural_net, img, eps)
    true_label = labels[i]
    
    for j in 1:10
        if j != true_label
            target_label = j
            last_layer = last(neural_net.weights)
            objective = zeros(10)
            objective[target_label] = 1.0
            objective[true_label] = -1.0
            c = last_layer * objective
            num_layers = length(neural_net.weights)
            final_dim, output_dim = size(last_layer)
            @objective(mip, Max, sum(c[i]*mip[:x][num_layers, i] for i in 1:final_dim))
            optimize!(mip)
            opt_val = getobjectivevalue(mip)
            if opt_val > 0
                robust -= 1
                break
            end
        end
    end
end
# Out:
# verified image number %i1
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i2
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i3
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i4
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i5
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i6
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i7
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i8
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i9
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i10
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i11
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i12
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i13
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i14
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i15
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i16
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i17
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i18
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i19
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i20
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i21
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i22
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i23
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i24
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i25
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i26
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i27
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i28
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i29
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i30
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i31
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i32
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i33
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i34
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i35
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i36
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i37
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i38
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i39
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i40
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i41
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i42
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i43
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i44
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i45
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i46
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i47
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i48
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i49
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i50
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i51
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i52
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i53
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i54
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i55
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i56
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i57
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i58
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i59
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i60
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i61
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i62
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i63
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i64
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i65
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i66
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i67
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i68
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i69
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i70
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i71
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i72
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i73
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i74
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i75
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i76
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i77
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i78
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i79
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i80
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i81
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i82
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i83
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i84
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i85
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i86
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i87
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i88
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i89
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i90
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i91
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i92
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i93
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i94
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i95
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i96
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i97
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i98
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i99
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i100
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i101
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i102
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i103
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i104
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i105
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i106
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i107
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i108
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i109
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i110
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i111
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i112
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i113
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i114
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i115
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i116
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i117
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i118
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i119
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i120
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i121
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i122
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i123
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i124
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i125
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i126
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i127
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i128
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i129
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i130
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i131
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i132
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i133
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i134
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i135
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i136
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i137
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i138
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i139
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i140
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i141
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i142
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i143
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i144
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i145
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i146
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i147
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i148
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i149
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18
# verified image number %i150
# --------------------------------------------
# Warning: your license will expire in 14 days
# --------------------------------------------
#
# Academic license - for non-commercial use only - expires 2022-05-18

# %%
robust
# Out:
# 138

# %%
using Suppressor
eps = 0.024
robust = 150
for (i,img) in enumerate(imgs)
    @suppress begin
        mip, variable_neuron_dict, neuron_integervar_dict = init_mip_deeppoly(neural_net, img, eps)
        true_label = labels[i]

        for j in 1:10
            if j != true_label
                target_label = j
                last_layer = last(neural_net.weights)
                objective = zeros(10)
                objective[target_label] = 1.0
                objective[true_label] = -1.0
                c = last_layer * objective
                num_layers = length(neural_net.weights)
                final_dim, output_dim = size(last_layer)
                @objective(mip, Max, sum(c[i]*mip[:x][num_layers, i] for i in 1:final_dim))
                optimize!(mip)
                opt_val = getobjectivevalue(mip)
                if opt_val > 0
                    robust -= 1
                    break
                end
            end
        end
    end
end

# %%
mip, variable_neuron_dict, neuron_integervar_dict = init_mip_deeppoly(neural_net, imgs[1], eps)
target_label = 2
true_label = 8
last_layer = last(neural_net.weights)
objective = zeros(10)
objective[target_label] = 1.0
objective[true_label] = -1.0
c = last_layer * objective
num_layers = length(neural_net.weights)
final_dim, output_dim = size(last_layer)
@objective(mip, Max, sum(c[i]*mip[:x][num_layers, i] for i in 1:final_dim))
optimize!(mip)
opt_val = getobjectivevalue(mip)
# Out:
# -14.704651959823078

# %% [markdown]
# # Cayley Embedding

# %%
eps = 0.008
robust = 150
for (i,img) in enumerate(imgs[1:2])
    @suppress begin
        true_label = labels[i]
        for j in 1:10
            if j != true_label
                target_label = j
                opt_val, opt_sol_x, opt_sol_z, mip = target_attack(neural_net, img, true_label, target_label, eps)
                if opt_val > 0
                    robust -= 1
                    break
                end
            end
        end
    end
end

# %%
@time opt_val, opt_sol_x, opt_sol_z, mip = target_attack(neural_net, imgs[1], 8, 2, eps)
# Out:
#   2.062169 seconds (12.40 M allocations: 3.535 GiB, 11.97% gc time, 42.35% compilation time)
# (-14.716536326287843,   [1, 1  ]  =  -1.0
#   [1, 10 ]  =  -0.992
#   [1, 100]  =  -1.0
#   [1, 101]  =  -0.992
#   [1, 102]  =  -1.0
#   [1, 103]  =  -1.0
#   [1, 104]  =  -1.0
#   [1, 105]  =  -0.998541
#   [1, 106]  =  -0.992
#   [1, 107]  =  -1.0
#             ⋮
#   [3, 9  ]  =  1.0
#   [3, 90 ]  =  -1.0
#   [3, 91 ]  =  -1.0
#   [3, 92 ]  =  -1.0
#   [3, 93 ]  =  -1.0
#   [3, 94 ]  =  1.0
#   [3, 95 ]  =  1.0
#   [3, 96 ]  =  -1.0
#   [3, 97 ]  =  -1.0
#   [3, 98 ]  =  -1.0
#   [3, 99 ]  =  -1.0,   [2, 1, 1  ]  =  1.0
#   [2, 10, 1 ]  =  1.0
#   [2, 100, 1]  =  1.0
#   [2, 101, 1]  =  1.0
#   [2, 102, 1]  =  0.0
#   [2, 102, 2]  =  1.0
#   [2, 103, 1]  =  1.0
#   [2, 104, 1]  =  1.0
#   [2, 105, 1]  =  1.0
#   [2, 106, 1]  =  1.0
#                ⋮
#   [3, 92, 1 ]  =  1.0
#   [3, 93, 1 ]  =  1.0
#   [3, 94, 1 ]  =  1.0
#   [3, 95, 1 ]  =  1.0
#   [3, 96, 1 ]  =  1.0
#   [3, 96, 2 ]  =  0.0
#   [3, 97, 1 ]  =  1.0
#   [3, 98, 1 ]  =  1.0
#   [3, 98, 2 ]  =  0.0
#   [3, 98, 3 ]  =  0.0
#   [3, 99, 1 ]  =  1.0, A JuMP Model
# Maximization problem with:
# Variables: 1928
# Objective function type: AffExpr
# `AffExpr`-in-`MathOptInterface.EqualTo{Float64}`: 1024 constraints
# `AffExpr`-in-`MathOptInterface.GreaterThan{Float64}`: 527 constraints
# `AffExpr`-in-`MathOptInterface.LessThan{Float64}`: 527 constraints
# `AffExpr`-in-`MathOptInterface.Interval{Float64}`: 1552 constraints
# `VariableRef`-in-`MathOptInterface.GreaterThan{Float64}`: 632 constraints
# `VariableRef`-in-`MathOptInterface.LessThan{Float64}`: 632 constraints
# Model mode: AUTOMATIC
# CachingOptimizer state: ATTACHED_OPTIMIZER
# Solver name: Gurobi
# Names registered in the model: x, z)
